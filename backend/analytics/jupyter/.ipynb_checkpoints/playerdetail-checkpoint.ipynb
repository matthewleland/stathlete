# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
from nba_api.stats.endpoints import playerawards
# Lebron James
awards = playerawards.PlayerAwards(player_id='2544')
awards.get_data_frames()[0]
# Out:
#      PERSON_ID FIRST_NAME LAST_NAME                 TEAM  \
# 0         2544     LeBron     James  Cleveland Cavaliers
# 1         2544     LeBron     James  Cleveland Cavaliers
# 2         2544     LeBron     James           Miami Heat
# 3         2544     LeBron     James           Miami Heat
# 4         2544     LeBron     James           Miami Heat
# ..         ...        ...       ...                  ...
# 146       2544     LeBron     James                  USA
# 147       2544     LeBron     James                  USA
# 148       2544     LeBron     James                  USA
# 149       2544     LeBron     James   Los Angeles Lakers
# 150       2544     LeBron     James   Los Angeles Lakers
#
#                 DESCRIPTION ALL_NBA_TEAM_NUMBER   SEASON MONTH  \
# 0        All-Defensive Team                   1  2008-09  None
# 1        All-Defensive Team                   1  2009-10  None
# 2        All-Defensive Team                   1  2010-11  None
# ...

# %%
# Micheal Jordan
awards = playerawards.PlayerAwards(player_id='893')
awards.get_data_frames()[0]
# Out:
#     PERSON_ID FIRST_NAME LAST_NAME           TEAM  \
# 0         893    Michael    Jordan  Chicago Bulls
# 1         893    Michael    Jordan  Chicago Bulls
# 2         893    Michael    Jordan  Chicago Bulls
# 3         893    Michael    Jordan  Chicago Bulls
# 4         893    Michael    Jordan  Chicago Bulls
# ..        ...        ...       ...            ...
# 89        893    Michael    Jordan  Chicago Bulls
# 90        893    Michael    Jordan  Chicago Bulls
# 91        893    Michael    Jordan  Chicago Bulls
# 92        893    Michael    Jordan            USA
# 93        893    Michael    Jordan            USA
#
#                                           DESCRIPTION ALL_NBA_TEAM_NUMBER  \
# 0                                  All-Defensive Team                   1
# 1                                  All-Defensive Team                   1
# 2                                  All-Defensive Team                   1
# ...

# %%
from nba_api.stats.endpoints import playercareerstats
# Lebron James
career = playercareerstats.PlayerCareerStats(player_id='2544')
career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0        2544   2003-04        00  1610612739               CLE        19.0
# 1        2544   2004-05        00  1610612739               CLE        20.0
# 2        2544   2005-06        00  1610612739               CLE        21.0
# 3        2544   2006-07        00  1610612739               CLE        22.0
# 4        2544   2007-08        00  1610612739               CLE        23.0
# 5        2544   2008-09        00  1610612739               CLE        24.0
# 6        2544   2009-10        00  1610612739               CLE        25.0
# 7        2544   2010-11        00  1610612748               MIA        26.0
# 8        2544   2011-12        00  1610612748               MIA        27.0
# 9        2544   2012-13        00  1610612748               MIA        28.0
# 10       2544   2013-14        00  1610612748               MIA        29.0
# ...

# %%
# Micheal Jordan
career = playercareerstats.PlayerCareerStats(player_id='893')
career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0         893   1984-85        00  1610612741               CHI        22.0
# 1         893   1985-86        00  1610612741               CHI        23.0
# 2         893   1986-87        00  1610612741               CHI        24.0
# 3         893   1987-88        00  1610612741               CHI        25.0
# 4         893   1988-89        00  1610612741               CHI        26.0
# 5         893   1989-90        00  1610612741               CHI        27.0
# 6         893   1990-91        00  1610612741               CHI        28.0
# 7         893   1991-92        00  1610612741               CHI        29.0
# 8         893   1992-93        00  1610612741               CHI        30.0
# 9         893   1994-95        00  1610612741               CHI        32.0
# 10        893   1995-96        00  1610612741               CHI        33.0
# ...

# %%
df = career.get_data_frames()[0]
plt.figure(figsize = (15,15), dpi=200)
sns.barplot(x = 'PTS', y = 'GP', data = df)
# Out:
# <AxesSubplot:xlabel='PTS', ylabel='GP'>

# %%
df = career.get_data_frames()[0]
plt.figure(figsize = (15,15), dpi=200)
sns.barplot(x = 'SEASON_ID', y = 'PTS', data = df)
# Out:
# <AxesSubplot:xlabel='SEASON_ID', ylabel='PTS'>

# %%
# Lebron James
career = playercareerstats.PlayerCareerStats(player_id='2544')
career.get_data_frames()[0]


df = career.get_data_frames()[0]
plt.figure(figsize = (15,15), dpi=200)
sns.barplot(x = 'PTS', y = 'GP', data = df)
plt.title("Mapping Lebron James' Points/Games Played For Each Season")
# Out:
# Text(0.5, 1.0, "Mapping Lebron James' Points/Games Played For Each Season")

# %%
df = career.get_data_frames()[0]
plt.figure(figsize = (18,15), dpi=200)
sns.barplot(x = 'SEASON_ID', y = 'PTS', data = df)
plt.title("Points per Season for Lebron James")
# Out:
# Text(0.5, 1.0, 'Points per Season for Lebron James')

# %%
# Stephen Curry
awards = playerawards.PlayerAwards(player_id='201939')
awards.get_data_frames()[0]
# Out:
#     PERSON_ID FIRST_NAME LAST_NAME                   TEAM  \
# 0      201939    Stephen     Curry  Golden State Warriors
# 1      201939    Stephen     Curry  Golden State Warriors
# 2      201939    Stephen     Curry  Golden State Warriors
# 3      201939    Stephen     Curry  Golden State Warriors
# 4      201939    Stephen     Curry  Golden State Warriors
# 5      201939    Stephen     Curry  Golden State Warriors
# 6      201939    Stephen     Curry  Golden State Warriors
# 7      201939    Stephen     Curry  Golden State Warriors
# 8      201939    Stephen     Curry  Golden State Warriors
# 9      201939    Stephen     Curry  Golden State Warriors
# 10     201939    Stephen     Curry  Golden State Warriors
# 11     201939    Stephen     Curry  Golden State Warriors
# 12     201939    Stephen     Curry  Golden State Warriors
# 13     201939    Stephen     Curry  Golden State Warriors
# 14     201939    Stephen     Curry  Golden State Warriors
# ...

# %%
from nba_api.stats.endpoints import playercareerstats, playervsplayer

# LeBron James career stats
lj_career_stats = playercareerstats.PlayerCareerStats(player_id='2544')
lj_player_id = lj_career_stats.get_data_frames()[0]['PLAYER_ID'][0]

# Stephen Curry career stats
sc_career_stats = playercareerstats.PlayerCareerStats(player_id='201939')
sc_player_id = sc_career_stats.get_data_frames()[0]['PLAYER_ID'][0]

# Compare LeBron James vs Stephen Curry
playervs = playervsplayer.PlayerVsPlayer(player_id=lj_player_id, vs_player_id=sc_player_id)
playervs_df = playervs.get_data_frames()[0]

# Print the comparison table
print(playervs_df)
# Out:
#   GROUP_SET    GROUP_VALUE  PLAYER_ID    PLAYER_NAME  GP   W   L  W_PCT  \
# 0   Overall   LeBron James       2544   LeBron James  47  24  23  0.511
# 1   Overall  Stephen Curry     201939  Stephen Curry  42  21  21  0.500
#
#         MIN  FGM  ...  AST  TOV  STL  BLK  BLKA  PF  PFD   PTS  PLUS_MINUS  \
# 0  1695.185  532  ...  326  147   44   26    43  79  247  1388         147
# 1  1457.925  417  ...  265  139   41   16    30  93  170  1251         162
#
#    NBA_FANTASY_PTS
# 0           2415.2
# 1           1994.9
#
# [2 rows x 31 columns]

# %%
df = playervs.get_data_frames()[0]
plt.figure(figsize = (10,4), dpi=200) 
sns.scatterplot(x = 'GP', y = 'PTS', data = df, hue = 'GROUP_VALUE')
plt.title("Current Season Camparison")
# Out:
# Text(0.5, 1.0, 'Current Season Camparison')

# %%
df = playervs.get_data_frames()[0]
plt.figure(figsize = (10,4), dpi=200) 
sns.scatterplot(x = 'W', y = 'L', data = df, hue = 'GROUP_VALUE')
plt.title('Current Seasons Win vs Loss: Stephen Curry vs. LeBron James')
# Out:
# Text(0.5, 1.0, 'Current Seasons Win vs Loss: Stephen Curry vs. LeBron James')

# %%
df = playervs.get_data_frames()[0]
plt.figure(figsize = (10,4), dpi=200) 
sns.scatterplot(x = 'GP', y = 'AST', data = df, hue = 'GROUP_VALUE')
plt.title('Points/Games played Current Season')
# Out:
# Text(0.5, 1.0, 'Points/Games played Current Season')

# %%
# LeBron James career stats
lj_career_stats = playercareerstats.PlayerCareerStats(player_id='2544')
lj_player_id = lj_career_stats.get_data_frames()[0]['PLAYER_ID'][0]


# Kevin Durrant career stats
kd_career_stats = playercareerstats.PlayerCareerStats(player_id='201142')
kd_player_id = mj_career_stats.get_data_frames()[0]['PLAYER_ID'][0]


# Compare LeBron James vs Kevin Durrant
playervs_lj_kd = playervsplayer.PlayerVsPlayer(player_id=lj_player_id, vs_player_id=kd_player_id)
playervs_lj_kd_df = playervs_lj_kd.get_data_frames()[0]



# Print the comparison tables
print(playervs_lj_kd_df)
# Out:
#   GROUP_SET   GROUP_VALUE  PLAYER_ID   PLAYER_NAME  GP   W   L  W_PCT  \
# 0   Overall  LeBron James       2544  LeBron James  47  24  23  0.511
#
#         MIN  FGM  ...  AST  TOV  STL  BLK  BLKA  PF  PFD   PTS  PLUS_MINUS  \
# 0  1695.185  532  ...  326  147   44   26    43  79  247  1388         147
#
#    NBA_FANTASY_PTS
# 0           2415.2
#
# [1 rows x 31 columns]

# %%
from nba_api.stats.endpoints import playercareerstats, playervsplayer

# LeBron James career stats
lj_career_stats = playercareerstats.PlayerCareerStats(player_id='2544')
lj_player_id = lj_career_stats.get_data_frames()[0]['PLAYER_ID'][0]

# Kevin Durrant
kd_career_stats = playercareerstats.PlayerCareerStats(player_id='201142')
kd_player_id = kd_career_stats.get_data_frames()[0]['PLAYER_ID'][0]



playervs = playervsplayer.PlayerVsPlayer(player_id=lj_player_id, vs_player_id=kd_player_id)
playervs_df = playervs.get_data_frames()[0]

# Print the comparison table
print(playervs_df)
# Out:
#   GROUP_SET   GROUP_VALUE  PLAYER_ID   PLAYER_NAME  GP   W   L  W_PCT  \
# 0   Overall  LeBron James       2544  LeBron James  47  24  23  0.511
# 1   Overall  Kevin Durant     201142  Kevin Durant  42  29  13  0.690
#
#            MIN  FGM  ...  AST  TOV  STL  BLK  BLKA  PF  PFD   PTS  PLUS_MINUS  \
# 0  1695.185000  532  ...  326  147   44   26    43  79  247  1388         147
# 1  1500.653333  439  ...  218  142   33   61    22  97  251  1238         235
#
#    NBA_FANTASY_PTS
# 0           2415.2
# 1           2045.8
#
# [2 rows x 31 columns]

# %%
df = playervs.get_data_frames()[0]
plt.figure(figsize=(10, 4), dpi=200)
sns.lineplot(x='GP', y='AST', data=df, hue='GROUP_VALUE')
# Out:
# <AxesSubplot:xlabel='GP', ylabel='AST'>

# %%
# Get career points for Stephen Curry
curry_career = playercareerstats.PlayerCareerStats(player_id='201939')
curry_points = pd.DataFrame(curry_career.get_data_frames()[0][['PLAYER_AGE', 'PTS']])

# Get career points for LeBron James
james_career = playercareerstats.PlayerCareerStats(player_id='2544')
james_points = pd.DataFrame(james_career.get_data_frames()[0][['PLAYER_AGE', 'PTS']])

# Group points by age and sum over all seasons
curry_points = curry_points.groupby('PLAYER_AGE').sum()
james_points = james_points.groupby('PLAYER_AGE').sum()

# Merge data for both players
merged_points = pd.merge(curry_points, james_points, on='PLAYER_AGE', suffixes=('_Curry', '_James'))

# Create line plot
fig, ax = plt.subplots()
merged_points.plot(kind='line', ax=ax)
ax.set_xlabel('Age')
ax.set_ylabel('Points')
ax.set_title('Career Points Comparison: Stephen Curry vs. LeBron James')
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(merged_points.index, merged_points['PTS_Curry'], label='Stephen Curry')
ax.scatter(merged_points.index, merged_points['PTS_James'], label='LeBron James')
ax.set_xlabel('Age')
ax.set_ylabel('Points')
ax.set_title('Career Points Comparison: Stephen Curry vs. LeBron James')
ax.legend()
plt.show()

# %%
jordan_career = playercareerstats.PlayerCareerStats(player_id='893')
jordan_points = pd.DataFrame(jordan_career.get_data_frames()[0][['PLAYER_AGE', 'PTS']])

# Get career points for LeBron James
james_career = playercareerstats.PlayerCareerStats(player_id='2544')
james_points = pd.DataFrame(james_career.get_data_frames()[0][['PLAYER_AGE', 'PTS']])

# Group points by age and sum over all seasons
jordan_points = jordan_points.groupby('PLAYER_AGE').sum()
james_points = james_points.groupby('PLAYER_AGE').sum()

# Merge data for both players
merged_points = pd.merge(jordan_points, james_points, on='PLAYER_AGE', suffixes=('_Jordan', '_James'))

# Create line plot
fig, ax = plt.subplots()
merged_points.plot(kind='line', ax=ax)
ax.set_xlabel('Age')
ax.set_ylabel('Points')
ax.set_title('Career Points Comparison: Stephen Curry vs. LeBron James')
plt.show()

# %%
# Get career points for Michael Jordan
jordan_career = playercareerstats.PlayerCareerStats(player_id='893')
jordan_points = pd.DataFrame(jordan_career.get_data_frames()[0][['PLAYER_AGE', 'PTS']])
jordan_points = jordan_points.groupby('PLAYER_AGE').sum()

# Get career points for LeBron James
james_career = playercareerstats.PlayerCareerStats(player_id='2544')
james_points = pd.DataFrame(james_career.get_data_frames()[0][['PLAYER_AGE', 'PTS']])
james_points = james_points.groupby('PLAYER_AGE').sum()

#Curry 
curry_career = playercareerstats.PlayerCareerStats(player_id='201939')
curry_points = pd.DataFrame(curry_career.get_data_frames()[0][['PLAYER_AGE', 'PTS']])
curry_points = curry_points.groupby('PLAYER_AGE').sum()


merged_points = pd.merge(jordan_points, james_points, on='PLAYER_AGE', suffixes=('_Jordan', '_James'))
merged_points = pd.merge(merged_points, curry_points, on='PLAYER_AGE', suffixes=('','_Curry'))
# Display as table
print(merged_points)
# Out:
#             PTS_Jordan  PTS_James   PTS
# PLAYER_AGE
# 22.0              2313       2132  1399
# 23.0               408       2250  1373
# 24.0              3041       2304   383
# 25.0              2868       2258  1786
# 26.0              2633       2111  1873
# 27.0              2753       1683  1900
# 28.0              2580       2036  2375
# 29.0              2404       2089  1999
# 30.0              2541       1743  1346
# 32.0               457       1954   104
# 33.0              2491       2251  2015
# 34.0              2431       1505  2904

# %%
# Get career points for Michael Jordan
jordan_career = playercareerstats.PlayerCareerStats(player_id='893')
jordan_points = pd.DataFrame(jordan_career.get_data_frames()[0][['PLAYER_AGE', 'PTS']])

# Get career points for LeBron James
james_career = playercareerstats.PlayerCareerStats(player_id='2544')
james_points = pd.DataFrame(james_career.get_data_frames()[0][['PLAYER_AGE', 'PTS']])

# Get career points for Stephen Curry
curry_career = playercareerstats.PlayerCareerStats(player_id='201939')
curry_points = pd.DataFrame(curry_career.get_data_frames()[0][['PLAYER_AGE', 'PTS']])

# Group points by age and sum over all seasons
jordan_points = jordan_points.groupby('PLAYER_AGE').sum()
james_points = james_points.groupby('PLAYER_AGE').sum()
curry_points = curry_points.groupby('PLAYER_AGE').sum()

# Merge data for all players
merged_points = pd.merge(jordan_points, james_points, on='PLAYER_AGE', suffixes=('_Jordan', '_James'))
merged_points = pd.merge(merged_points, curry_points, on='PLAYER_AGE')

# Create scatter plot
fig, ax = plt.subplots()
ax.scatter(merged_points.index, merged_points['PTS_Jordan'], label='Michael Jordan')
ax.scatter(merged_points.index, merged_points['PTS_James'], label='LeBron James')
ax.scatter(merged_points.index, merged_points['PTS'], label='Stephen Curry')
ax.set_xlabel('Age')
ax.set_ylabel('Points')
ax.set_title('Career Points Comparison: Michael Jordan vs. LeBron James vs. Stephen Curry')
ax.legend()
plt.show()

# %%
# Get career points for Michael Jordan
jordan_career = playercareerstats.PlayerCareerStats(player_id='893')
jordan_points = pd.DataFrame(jordan_career.get_data_frames()[0][['PLAYER_AGE', 'PTS']])

# Get career points for LeBron James
james_career = playercareerstats.PlayerCareerStats(player_id='2544')
james_points = pd.DataFrame(james_career.get_data_frames()[0][['PLAYER_AGE', 'PTS']])

# Get career points for Stephen Curry
curry_career = playercareerstats.PlayerCareerStats(player_id='201939')
curry_points = pd.DataFrame(curry_career.get_data_frames()[0][['PLAYER_AGE', 'PTS']])

# Group points by age and sum over all seasons
jordan_points = jordan_points.groupby('PLAYER_AGE').sum()
james_points = james_points.groupby('PLAYER_AGE').sum()
curry_points = curry_points.groupby('PLAYER_AGE').sum()

# Merge data for all players
merged_points = pd.merge(jordan_points, james_points, on='PLAYER_AGE', suffixes=('_Jordan', '_James'))
merged_points = pd.merge(merged_points, curry_points, on='PLAYER_AGE')

# Create line plot
fig, ax = plt.subplots()
merged_points.plot(kind='line', ax=ax)
ax.set_xlabel('Age')
ax.set_ylabel('Points')
ax.set_title('Career Points Comparison: Michael Jordan vs. LeBron James vs. Stephen Curry')
ax.legend(['Michael Jordan', 'LeBron James', 'Stephen Curry'])
plt.show()
