# %%
from nba_api.stats.endpoints import playercareerstats
# Anthony Davis
career = playercareerstats.PlayerCareerStats(player_id='203076')
career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      203076   2012-13        00  1610612740               NOH        20.0
# 1      203076   2013-14        00  1610612740               NOP        21.0
# 2      203076   2014-15        00  1610612740               NOP        22.0
# 3      203076   2015-16        00  1610612740               NOP        23.0
# 4      203076   2016-17        00  1610612740               NOP        24.0
# 5      203076   2017-18        00  1610612740               NOP        25.0
# 6      203076   2018-19        00  1610612740               NOP        26.0
# 7      203076   2019-20        00  1610612747               LAL        27.0
# 8      203076   2020-21        00  1610612747               LAL        28.0
# 9      203076   2021-22        00  1610612747               LAL        29.0
# 10     203076   2022-23        00  1610612747               LAL        29.0
#
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ls
# Out:
# Player.ipynb        PlayerCharts.ipynb

# %%
#Lester Hudson
career = playercareerstats.PlayerCareerStats(player_id='201991')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     201991   2009-10        00  1610612738               BOS        25.0
# 1     201991   2009-10        00  1610612763               MEM        25.0
# 2     201991   2009-10        00           0               TOT        25.0
# 3     201991   2010-11        00  1610612764               WAS        26.0
# 4     201991   2011-12        00  1610612739               CLE        27.0
# 5     201991   2011-12        00  1610612763               MEM        27.0
# 6     201991   2011-12        00           0               TOT        27.0
# 7     201991   2014-15        00  1610612746               LAC        30.0
#
#    GP  GS    MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0  16   0   70.0    7  ...   0.833     3     5    8    8    3    2    9   7
# 1   9   0   61.0   14  ...   0.857     4     6   10    5    5    1    5   5
# ...

# %%
#Nikola Jokic
career = playercareerstats.PlayerCareerStats(player_id='203999')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203999   2015-16        00  1610612743               DEN        21.0
# 1     203999   2016-17        00  1610612743               DEN        22.0
# 2     203999   2017-18        00  1610612743               DEN        23.0
# 3     203999   2018-19        00  1610612743               DEN        24.0
# 4     203999   2019-20        00  1610612743               DEN        25.0
# 5     203999   2020-21        00  1610612743               DEN        26.0
# 6     203999   2021-22        00  1610612743               DEN        27.0
# 7     203999   2022-23        00  1610612743               DEN        28.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB   REB  AST  STL  BLK  TOV  \
# 0  80  55  1733.0  307  ...   0.811   181   379   560  189   79   50  104
# 1  73  59  2038.0  494  ...   0.825   212   506   718  359   61   55  171
# ...

# %%
#Stephen Curry
career = playercareerstats.PlayerCareerStats(player_id='201939')
career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      201939   2009-10        00  1610612744               GSW        22.0
# 1      201939   2010-11        00  1610612744               GSW        23.0
# 2      201939   2011-12        00  1610612744               GSW        24.0
# 3      201939   2012-13        00  1610612744               GSW        25.0
# 4      201939   2013-14        00  1610612744               GSW        26.0
# 5      201939   2014-15        00  1610612744               GSW        27.0
# 6      201939   2015-16        00  1610612744               GSW        28.0
# 7      201939   2016-17        00  1610612744               GSW        29.0
# 8      201939   2017-18        00  1610612744               GSW        30.0
# 9      201939   2018-19        00  1610612744               GSW        31.0
# 10     201939   2019-20        00  1610612744               GSW        32.0
# ...

# %%
#Kevin Durrant
career = playercareerstats.PlayerCareerStats(player_id='201142')
career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      201142   2007-08        00  1610612760               SEA        19.0
# 1      201142   2008-09        00  1610612760               OKC        20.0
# 2      201142   2009-10        00  1610612760               OKC        21.0
# 3      201142   2010-11        00  1610612760               OKC        22.0
# 4      201142   2011-12        00  1610612760               OKC        23.0
# 5      201142   2012-13        00  1610612760               OKC        24.0
# 6      201142   2013-14        00  1610612760               OKC        25.0
# 7      201142   2014-15        00  1610612760               OKC        26.0
# 8      201142   2015-16        00  1610612760               OKC        27.0
# 9      201142   2016-17        00  1610612744               GSW        28.0
# 10     201142   2017-18        00  1610612744               GSW        29.0
# ...

# %%
#Lebron James
career = playercareerstats.PlayerCareerStats(player_id='2544')
career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0        2544   2003-04        00  1610612739               CLE        19.0
# 1        2544   2004-05        00  1610612739               CLE        20.0
# 2        2544   2005-06        00  1610612739               CLE        21.0
# 3        2544   2006-07        00  1610612739               CLE        22.0
# 4        2544   2007-08        00  1610612739               CLE        23.0
# 5        2544   2008-09        00  1610612739               CLE        24.0
# 6        2544   2009-10        00  1610612739               CLE        25.0
# 7        2544   2010-11        00  1610612748               MIA        26.0
# 8        2544   2011-12        00  1610612748               MIA        27.0
# 9        2544   2012-13        00  1610612748               MIA        28.0
# 10       2544   2013-14        00  1610612748               MIA        29.0
# ...

# %%
#Trae Young
career = playercareerstats.PlayerCareerStats(player_id='1629027')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1629027   2018-19        00  1610612737               ATL        20.0
# 1    1629027   2019-20        00  1610612737               ATL        21.0
# 2    1629027   2020-21        00  1610612737               ATL        22.0
# 3    1629027   2021-22        00  1610612737               ATL        23.0
# 4    1629027   2022-23        00  1610612737               ATL        24.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  81  81  2503.0  525  ...   0.829    64   237  301  653   72   15  308  140
# 1  60  60  2120.0  546  ...   0.860    32   223  255  560   65    8  289  104
# 2  63  63  2125.0  487  ...   0.886    38   207  245  594   53   12  261  111
# 3  76  76  2652.0  711  ...   0.904    50   234  284  737   72    7  303  128
# 4  54  54  1907.0  458  ...   0.889    39   120  159  550   57    8  221   83
#
#     PTS
# 0  1549
# 1  1778
# 2  1594
# ...

# %%
#Jayson Tatum
career = playercareerstats.PlayerCareerStats(player_id='1628369')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628369   2017-18        00  1610612738               BOS        20.0
# 1    1628369   2018-19        00  1610612738               BOS        21.0
# 2    1628369   2019-20        00  1610612738               BOS        22.0
# 3    1628369   2020-21        00  1610612738               BOS        23.0
# 4    1628369   2021-22        00  1610612738               BOS        24.0
# 5    1628369   2022-23        00  1610612738               BOS        24.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  80  80  2443.0  397  ...   0.826    50   352  402  128   83   58  114  170
# 1  79  79  2455.0  466  ...   0.855    70   407  477  168   84   57  122  168
# 2  66  66  2265.0  552  ...   0.812    64   396  460  200   93   57  155  136
# 3  64  64  2290.0  605  ...   0.868    50   422  472  276   75   31  171  122
# ...

# %%
#Terry Rozier
career = playercareerstats.PlayerCareerStats(player_id='1626179')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1626179   2015-16        00  1610612738               BOS        22.0
# 1    1626179   2016-17        00  1610612738               BOS        23.0
# 2    1626179   2017-18        00  1610612738               BOS        24.0
# 3    1626179   2018-19        00  1610612738               BOS        25.0
# 4    1626179   2019-20        00  1610612766               CHA        26.0
# 5    1626179   2020-21        00  1610612766               CHA        27.0
# 6    1626179   2021-22        00  1610612766               CHA        28.0
# 7    1626179   2022-23        00  1610612766               CHA        28.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  39   0   311.0   29  ...   0.800    24    39   63   37    6    1   19   23
# 1  74   0  1263.0  151  ...   0.773    40   187  227  131   45   11   47   69
# ...

# %%
#DeMar DeRozan
career = playercareerstats.PlayerCareerStats(player_id='201942')
career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      201942   2009-10        00  1610612761               TOR        20.0
# 1      201942   2010-11        00  1610612761               TOR        21.0
# 2      201942   2011-12        00  1610612761               TOR        22.0
# 3      201942   2012-13        00  1610612761               TOR        23.0
# 4      201942   2013-14        00  1610612761               TOR        24.0
# 5      201942   2014-15        00  1610612761               TOR        25.0
# 6      201942   2015-16        00  1610612761               TOR        26.0
# 7      201942   2016-17        00  1610612761               TOR        27.0
# 8      201942   2017-18        00  1610612761               TOR        28.0
# 9      201942   2018-19        00  1610612759               SAS        29.0
# 10     201942   2019-20        00  1610612759               SAS        30.0
# ...

# %%
#Donovan Mitchell
career = playercareerstats.PlayerCareerStats(player_id='1628378')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628378   2017-18        00  1610612762               UTA        21.0
# 1    1628378   2018-19        00  1610612762               UTA        22.0
# 2    1628378   2019-20        00  1610612762               UTA        23.0
# 3    1628378   2020-21        00  1610612762               UTA        24.0
# 4    1628378   2021-22        00  1610612762               UTA        25.0
# 5    1628378   2022-23        00  1610612739               CLE        26.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  79  71  2638.0  595  ...   0.805    52   244  296  291  118   27  215  213
# 1  77  77  2598.0  661  ...   0.806    59   257  316  322  106   31  218  208
# 2  69  69  2364.0  602  ...   0.863    53   251  304  294   70   14  184  172
# 3  53  53  1771.0  478  ...   0.845    50   185  235  277   52   15  147  117
# ...

# %%
#Luka Doncic
career = playercareerstats.PlayerCareerStats(player_id='1629029')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1629029   2018-19        00  1610612742               DAL        20.0
# 1    1629029   2019-20        00  1610612742               DAL        21.0
# 2    1629029   2020-21        00  1610612742               DAL        22.0
# 3    1629029   2021-22        00  1610612742               DAL        23.0
# 4    1629029   2022-23        00  1610612742               DAL        23.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  72  72  2318.0  506  ...   0.713    86   477  563  429   77   25  247  137
# 1  61  61  2047.0  581  ...   0.758    78   495  573  538   62   14  260  153
# 2  66  66  2262.0  647  ...   0.730    54   473  527  567   64   36  281  152
# 3  65  65  2301.0  641  ...   0.744    56   537  593  568   75   36  292  145
# 4  52  52  1892.0  580  ...   0.732    45   412  457  422   79   26  190  137
#
#     PTS
# 0  1526
# 1  1759
# 2  1830
# ...

# %%
#Cory Joseph
career = playercareerstats.PlayerCareerStats(player_id='202709')
career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      202709   2011-12        00  1610612759               SAS        20.0
# 1      202709   2012-13        00  1610612759               SAS        21.0
# 2      202709   2013-14        00  1610612759               SAS        22.0
# 3      202709   2014-15        00  1610612759               SAS        23.0
# 4      202709   2015-16        00  1610612761               TOR        24.0
# 5      202709   2016-17        00  1610612761               TOR        25.0
# 6      202709   2017-18        00  1610612754               IND        26.0
# 7      202709   2018-19        00  1610612754               IND        27.0
# 8      202709   2019-20        00  1610612758               SAC        28.0
# 9      202709   2020-21        00  1610612758               SAC        29.0
# 10     202709   2020-21        00  1610612765               DET        29.0
# ...

# %%
#Frank Kaminsky
career = playercareerstats.PlayerCareerStats(player_id='1626163')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1626163   2015-16        00  1610612766               CHA        23.0
# 1    1626163   2016-17        00  1610612766               CHA        24.0
# 2    1626163   2017-18        00  1610612766               CHA        25.0
# 3    1626163   2018-19        00  1610612766               CHA        26.0
# 4    1626163   2019-20        00  1610612756               PHX        27.0
# 5    1626163   2020-21        00  1610612756               PHX        28.0
# 6    1626163   2021-22        00  1610612756               PHX        29.0
# 7    1626163   2022-23        00  1610612737               ATL        29.0
# 8    1626163   2022-23        00  1610612745               HOU        29.0
# 9    1626163   2022-23        00           0               TOT        29.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# ...

# %%
#Buddy Heild
career = playercareerstats.PlayerCareerStats(player_id='1627741')
career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     1627741   2016-17        00  1610612740               NOP        24.0
# 1     1627741   2016-17        00  1610612758               SAC        24.0
# 2     1627741   2016-17        00           0               TOT        24.0
# 3     1627741   2017-18        00  1610612758               SAC        25.0
# 4     1627741   2018-19        00  1610612758               SAC        26.0
# 5     1627741   2019-20        00  1610612758               SAC        27.0
# 6     1627741   2020-21        00  1610612758               SAC        28.0
# 7     1627741   2021-22        00  1610612758               SAC        29.0
# 8     1627741   2021-22        00  1610612754               IND        29.0
# 9     1627741   2021-22        00           0               TOT        29.0
# 10    1627741   2022-23        00  1610612754               IND        30.0
#
# ...

# %%
#Tyus Jones
career = playercareerstats.PlayerCareerStats(player_id='1626145')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1626145   2015-16        00  1610612750               MIN        20.0
# 1    1626145   2016-17        00  1610612750               MIN        21.0
# 2    1626145   2017-18        00  1610612750               MIN        22.0
# 3    1626145   2018-19        00  1610612750               MIN        23.0
# 4    1626145   2019-20        00  1610612763               MEM        24.0
# 5    1626145   2020-21        00  1610612763               MEM        25.0
# 6    1626145   2021-22        00  1610612763               MEM        26.0
# 7    1626145   2022-23        00  1610612763               MEM        26.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  37   0   573.0   56  ...   0.718     7    40   47  108   31    3   33   33
# 1  60   0   774.0   75  ...   0.767    10    57   67  156   48    5   38   50
# ...

# %%
#Jimmy Butler
career = playercareerstats.PlayerCareerStats(player_id='202710')
career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      202710   2011-12        00  1610612741               CHI        22.0
# 1      202710   2012-13        00  1610612741               CHI        23.0
# 2      202710   2013-14        00  1610612741               CHI        24.0
# 3      202710   2014-15        00  1610612741               CHI        25.0
# 4      202710   2015-16        00  1610612741               CHI        26.0
# 5      202710   2016-17        00  1610612741               CHI        27.0
# 6      202710   2017-18        00  1610612750               MIN        28.0
# 7      202710   2018-19        00  1610612750               MIN        29.0
# 8      202710   2018-19        00  1610612755               PHI        29.0
# 9      202710   2018-19        00           0               TOT        29.0
# 10     202710   2019-20        00  1610612748               MIA        30.0
# ...

# %%
#Giannis Antetokounmpo
career = playercareerstats.PlayerCareerStats(player_id='203507')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203507   2013-14        00  1610612749               MIL        19.0
# 1     203507   2014-15        00  1610612749               MIL        20.0
# 2     203507   2015-16        00  1610612749               MIL        21.0
# 3     203507   2016-17        00  1610612749               MIL        22.0
# 4     203507   2017-18        00  1610612749               MIL        23.0
# 5     203507   2018-19        00  1610612749               MIL        24.0
# 6     203507   2019-20        00  1610612749               MIL        25.0
# 7     203507   2020-21        00  1610612749               MIL        26.0
# 8     203507   2021-22        00  1610612749               MIL        27.0
# 9     203507   2022-23        00  1610612749               MIL        28.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# ...

# %%
#Kyle Anderson
career = playercareerstats.PlayerCareerStats(player_id='203937')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203937   2014-15        00  1610612759               SAS        21.0
# 1     203937   2015-16        00  1610612759               SAS        22.0
# 2     203937   2016-17        00  1610612759               SAS        23.0
# 3     203937   2017-18        00  1610612759               SAS        24.0
# 4     203937   2018-19        00  1610612763               MEM        25.0
# 5     203937   2019-20        00  1610612763               MEM        26.0
# 6     203937   2020-21        00  1610612763               MEM        27.0
# 7     203937   2021-22        00  1610612763               MEM        28.0
# 8     203937   2022-23        00  1610612750               MIN        29.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  33   8   358.0   31  ...   0.643     5    67   72   28   15    7   10   28
# ...

# %%
#Brandon Ingram
career = playercareerstats.PlayerCareerStats(player_id='1627742')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1627742   2016-17        00  1610612747               LAL        19.0
# 1    1627742   2017-18        00  1610612747               LAL        20.0
# 2    1627742   2018-19        00  1610612747               LAL        21.0
# 3    1627742   2019-20        00  1610612740               NOP        22.0
# 4    1627742   2020-21        00  1610612740               NOP        23.0
# 5    1627742   2021-22        00  1610612740               NOP        24.0
# 6    1627742   2022-23        00  1610612740               NOP        25.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  79  40  2279.0  276  ...   0.621    60   256  316  166   50   36  116  158
# 1  59  59  1975.0  358  ...   0.681    57   257  314  230   45   43  149  163
# 2  52  52  1761.0  362  ...   0.675    41   226  267  154   28   31  129  149
# ...

# %%
#Julius Randle
career = playercareerstats.PlayerCareerStats(player_id='203944')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203944   2014-15        00  1610612747               LAL        20.0
# 1     203944   2015-16        00  1610612747               LAL        21.0
# 2     203944   2016-17        00  1610612747               LAL        22.0
# 3     203944   2017-18        00  1610612747               LAL        23.0
# 4     203944   2018-19        00  1610612740               NOP        24.0
# 5     203944   2019-20        00  1610612752               NYK        25.0
# 6     203944   2020-21        00  1610612752               NYK        26.0
# 7     203944   2021-22        00  1610612752               NYK        27.0
# 8     203944   2022-23        00  1610612752               NYK        28.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0   1   0    14.0    1  ...   0.000     0     0    0    0    0    0    1    1
# ...

# %%
#Shai Gilgeous-Alexander
career = playercareerstats.PlayerCareerStats(player_id='1628983')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628983   2018-19        00  1610612746               LAC        20.0
# 1    1628983   2019-20        00  1610612760               OKC        21.0
# 2    1628983   2020-21        00  1610612760               OKC        22.0
# 3    1628983   2021-22        00  1610612760               OKC        23.0
# 4    1628983   2022-23        00  1610612760               OKC        24.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  82  73  2174.0  341  ...   0.800    57   175  232  270   96   45  141  175
# 1  70  70  2428.0  478  ...   0.807    47   365  412  232   79   47  134  117
# 2  35  35  1180.0  287  ...   0.808    19   147  166  207   27   23  106   70
# 3  56  56  1942.0  477  ...   0.810    37   241  278  331   71   46  154  142
# 4  54  54  1918.0  553  ...   0.908    48   208  256  307   89   58  155  145
#
#     PTS
# 0   889
# 1  1331
# 2   830
# ...

# %%
#Wendell Carter Jr
career = playercareerstats.PlayerCareerStats(player_id='1628976')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628976   2018-19        00  1610612741               CHI        20.0
# 1    1628976   2019-20        00  1610612741               CHI        21.0
# 2    1628976   2020-21        00  1610612741               CHI        22.0
# 3    1628976   2020-21        00  1610612753               ORL        22.0
# 4    1628976   2020-21        00           0               TOT        22.0
# 5    1628976   2021-22        00  1610612753               ORL        23.0
# 6    1628976   2022-23        00  1610612753               ORL        23.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  44  44  1110.0  180  ...   0.795    87   220  307   78   26   58   65  152
# 1  43  43  1256.0  183  ...   0.737   139   266  405   51   33   36   72  162
# 2  32  25   792.0  129  ...   0.739    70   180  250   69   18   24   49   96
# ...

# %%
#Joel Embiid
career = playercareerstats.PlayerCareerStats(player_id='203954')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203954   2016-17        00  1610612755               PHI        23.0
# 1     203954   2017-18        00  1610612755               PHI        24.0
# 2     203954   2018-19        00  1610612755               PHI        25.0
# 3     203954   2019-20        00  1610612755               PHI        26.0
# 4     203954   2020-21        00  1610612755               PHI        27.0
# 5     203954   2021-22        00  1610612755               PHI        28.0
# 6     203954   2022-23        00  1610612755               PHI        28.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  31  31   786.0  200  ...   0.783    61   182  243   66   27   76  117  112
# 1  63  63  1912.0  510  ...   0.769   143   547  690  199   40  111  234  209
# 2  64  64  2154.0  580  ...   0.804   160   711  871  234   46  122  226  211
# ...

# %%
#Devin Booker
career = playercareerstats.PlayerCareerStats(player_id='1626164')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1626164   2015-16        00  1610612756               PHX        19.0
# 1    1626164   2016-17        00  1610612756               PHX        20.0
# 2    1626164   2017-18        00  1610612756               PHX        21.0
# 3    1626164   2018-19        00  1610612756               PHX        22.0
# 4    1626164   2019-20        00  1610612756               PHX        23.0
# 5    1626164   2020-21        00  1610612756               PHX        24.0
# 6    1626164   2021-22        00  1610612756               PHX        25.0
# 7    1626164   2022-23        00  1610612756               PHX        26.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  76  51  2108.0  367  ...   0.840    27   160  187  200   44   20  160  225
# 1  78  78  2731.0  606  ...   0.832    46   203  249  268   72   21  241  242
# ...

# %%
#Damian Lillard
career = playercareerstats.PlayerCareerStats(player_id='203081')
career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      203081   2012-13        00  1610612757               POR        22.0
# 1      203081   2013-14        00  1610612757               POR        23.0
# 2      203081   2014-15        00  1610612757               POR        24.0
# 3      203081   2015-16        00  1610612757               POR        25.0
# 4      203081   2016-17        00  1610612757               POR        26.0
# 5      203081   2017-18        00  1610612757               POR        27.0
# 6      203081   2018-19        00  1610612757               POR        28.0
# 7      203081   2019-20        00  1610612757               POR        29.0
# 8      203081   2020-21        00  1610612757               POR        30.0
# 9      203081   2021-22        00  1610612757               POR        31.0
# 10     203081   2022-23        00  1610612757               POR        32.0
#
# ...

# %%
#Domantas Sabonis
career = playercareerstats.PlayerCareerStats(player_id='1627734')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1627734   2016-17        00  1610612760               OKC        21.0
# 1    1627734   2017-18        00  1610612754               IND        22.0
# 2    1627734   2018-19        00  1610612754               IND        23.0
# 3    1627734   2019-20        00  1610612754               IND        24.0
# 4    1627734   2020-21        00  1610612754               IND        25.0
# 5    1627734   2021-22        00  1610612754               IND        26.0
# 6    1627734   2021-22        00  1610612758               SAC        26.0
# 7    1627734   2021-22        00           0               TOT        26.0
# 8    1627734   2022-23        00  1610612758               SAC        26.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  81  66  1631.0  192  ...   0.657    46   242  288   82   39   32   83  200
# ...

# %%
#Devonte' Graham
career = playercareerstats.PlayerCareerStats(player_id='1628984')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628984   2018-19        00  1610612766               CHA        24.0
# 1    1628984   2019-20        00  1610612766               CHA        25.0
# 2    1628984   2020-21        00  1610612766               CHA        26.0
# 3    1628984   2021-22        00  1610612740               NOP        27.0
# 4    1628984   2022-23        00  1610612740               NOP        28.0
# 5    1628984   2022-23        00  1610612759               SAS        28.0
# 6    1628984   2022-23        00           0               TOT        28.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  46   3   676.0   74  ...   0.761    10    53   63  121   23    2   30   48
# 1  63  53  2211.0  368  ...   0.820    42   170  212  471   62   15  181  115
# 2  55  44  1659.0  252  ...   0.842    22   126  148  295   48    6   84   77
# ...

# %%
#Pascal Siakam
career = playercareerstats.PlayerCareerStats(player_id='1627783')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1627783   2016-17        00  1610612761               TOR        23.0
# 1    1627783   2017-18        00  1610612761               TOR        24.0
# 2    1627783   2018-19        00  1610612761               TOR        25.0
# 3    1627783   2019-20        00  1610612761               TOR        26.0
# 4    1627783   2020-21        00  1610612761               TOR        27.0
# 5    1627783   2021-22        00  1610612761               TOR        28.0
# 6    1627783   2022-23        00  1610612761               TOR        28.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  55  38   859.0  103  ...   0.688    64   121  185   17   26   45   33  109
# 1  81   5  1679.0  253  ...   0.621    79   285  364  159   62   42   67  166
# 2  80  79  2548.0  519  ...   0.785   124   425  549  248   73   52  154  241
# ...

# %%
#Collin Sexton
career = playercareerstats.PlayerCareerStats(player_id='1629012')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1629012   2018-19        00  1610612739               CLE        20.0
# 1    1629012   2019-20        00  1610612739               CLE        21.0
# 2    1629012   2020-21        00  1610612739               CLE        22.0
# 3    1629012   2021-22        00  1610612739               CLE        23.0
# 4    1629012   2022-23        00  1610612762               UTA        24.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  82  72  2605.0  519  ...   0.839    57   179  236  243   44    6  185  186
# 1  65  65  2143.0  513  ...   0.846    61   143  204  192   65    7  158  142
# 2  60  60  2115.0  525  ...   0.815    58   129  187  262   62   10  167  157
# 3  11  11   316.0   68  ...   0.744    13    23   36   23   10    0   31   25
# 4  47  15  1129.0  230  ...   0.822    37    67  104  135   27    6   84  109
#
#     PTS
# 0  1371
# 1  1349
# 2  1460
# ...

# %%
#Bradley Beal
career = playercareerstats.PlayerCareerStats(player_id='203078')
career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      203078   2012-13        00  1610612764               WAS        20.0
# 1      203078   2013-14        00  1610612764               WAS        21.0
# 2      203078   2014-15        00  1610612764               WAS        22.0
# 3      203078   2015-16        00  1610612764               WAS        23.0
# 4      203078   2016-17        00  1610612764               WAS        24.0
# 5      203078   2017-18        00  1610612764               WAS        25.0
# 6      203078   2018-19        00  1610612764               WAS        26.0
# 7      203078   2019-20        00  1610612764               WAS        27.0
# 8      203078   2020-21        00  1610612764               WAS        28.0
# 9      203078   2021-22        00  1610612764               WAS        29.0
# 10     203078   2022-23        00  1610612764               WAS        29.0
#
# ...

# %%
df = career.get_data_frames()[0]
plt.figure(figsize = (6,4), dpi=200)
sns.scatterplot(x = 'PTS', y = 'GP', data = df)
# Out:
# <AxesSubplot:xlabel='PTS', ylabel='GP'>

# %%
#Lebron James
career = playercareerstats.PlayerCareerStats(player_id='2544')
career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0        2544   2003-04        00  1610612739               CLE        19.0
# 1        2544   2004-05        00  1610612739               CLE        20.0
# 2        2544   2005-06        00  1610612739               CLE        21.0
# 3        2544   2006-07        00  1610612739               CLE        22.0
# 4        2544   2007-08        00  1610612739               CLE        23.0
# 5        2544   2008-09        00  1610612739               CLE        24.0
# 6        2544   2009-10        00  1610612739               CLE        25.0
# 7        2544   2010-11        00  1610612748               MIA        26.0
# 8        2544   2011-12        00  1610612748               MIA        27.0
# 9        2544   2012-13        00  1610612748               MIA        28.0
# 10       2544   2013-14        00  1610612748               MIA        29.0
# ...

# %%
df = career.get_data_frames()[0]
plt.figure(figsize = (6,4), dpi=200)
sns.scatterplot(x = 'PTS', y = 'GP', data = df)
# Out:
# <AxesSubplot:xlabel='PTS', ylabel='GP'>

# %%
#Stephen Curry
career = playercareerstats.PlayerCareerStats(player_id='201939')
career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      201939   2009-10        00  1610612744               GSW        22.0
# 1      201939   2010-11        00  1610612744               GSW        23.0
# 2      201939   2011-12        00  1610612744               GSW        24.0
# 3      201939   2012-13        00  1610612744               GSW        25.0
# 4      201939   2013-14        00  1610612744               GSW        26.0
# 5      201939   2014-15        00  1610612744               GSW        27.0
# 6      201939   2015-16        00  1610612744               GSW        28.0
# 7      201939   2016-17        00  1610612744               GSW        29.0
# 8      201939   2017-18        00  1610612744               GSW        30.0
# 9      201939   2018-19        00  1610612744               GSW        31.0
# 10     201939   2019-20        00  1610612744               GSW        32.0
# ...

# %%
df = career.get_data_frames()[0]
plt.figure(figsize = (6,4), dpi=200)
sns.scatterplot(x = 'PTS', y = 'GP', data = df)
# Out:
# <AxesSubplot:xlabel='PTS', ylabel='GP'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='PTS',data=df,hue='PLAYER_ID')
# Out:
# <AxesSubplot:xlabel='PTS', ylabel='count'>

# %%
# Retrieve career statistics for Stephen Curry
curry_career = playercareerstats.PlayerCareerStats(player_id='201939')
curry_df = curry_career.get_data_frames()[0]

# Retrieve career statistics for LeBron James
james_career = playercareerstats.PlayerCareerStats(player_id='2544')
james_df = james_career.get_data_frames()[0]

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='PTS',data=df,hue='PLAYER_ID')
# Out:
# <AxesSubplot:xlabel='PTS', ylabel='count'>

# %%
career = playercareerstats.PlayerCareerStats()
career.get_data_frames()[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/y6/5kqztby116b345gq95p7_9lr0000gn/T/ipykernel_35094/885128635.py in <module>
# ----> 1 career = playercareerstats.PlayerCareerStats()
#       2 career.get_data_frames()[0]
#
# TypeError: __init__() missing 1 required positional argument: 'player_id'

# %%
df = career.get_data_frames()[0]

# %%
df.head()

# %%
# Stephen Curry
curry_career = playercareerstats.PlayerCareerStats(player_id='201939')
curry_stats = curry_career.get_data_frames()[0]

# LeBron James
james_career = playercareerstats.PlayerCareerStats(player_id='2544')
james_stats = james_career.get_data_frames()[0]

# %%
#Stephen Curry
career = playercareerstats.PlayerCareerStats(player_id='201939')
career.get_data_frames()[0]

#Lebron James
career = playercareerstats.PlayerCareerStats(player_id='2544')
career.get_data_frames()[0]

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Get career points for Stephen Curry
curry_career = playercareerstats.PlayerCareerStats(player_id='201939')
curry_points = pd.DataFrame(curry_career.get_data_frames()[0][['SEASON_ID', 'PTS']])

# Get career points for LeBron James
james_career = playercareerstats.PlayerCareerStats(player_id='2544')
james_points = pd.DataFrame(james_career.get_data_frames()[0][['SEASON_ID', 'PTS']])

# Merge data for both players
merged_points = pd.merge(curry_points, james_points, on='SEASON_ID', suffixes=('_Curry', '_James'))

# Create bar plot
fig, ax = plt.subplots()
merged_points.plot(kind='barh', x='SEASON_ID', ax=ax)
ax.set_xlabel('Points')
ax.set_ylabel('Season')
ax.set_title('Career Points Comparison: Stephen Curry vs. LeBron James')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Get career points for Stephen Curry
curry_career = playercareerstats.PlayerCareerStats(player_id='201939')
curry_points = pd.DataFrame(curry_career.get_data_frames()[0][['SEASON_ID', 'PTS']])

# Get career points for LeBron James
james_career = playercareerstats.PlayerCareerStats(player_id='2544')
james_points = pd.DataFrame(james_career.get_data_frames()[0][['SEASON_ID', 'PTS']])

# Merge data for both players
merged_points = pd.merge(curry_points, james_points, on='SEASON_ID', suffixes=('_Curry', '_James'))

# Create vertical bar plot
fig, ax = plt.subplots()
merged_points.plot(kind='bar', x='SEASON_ID', ax=ax)
ax.set_xlabel('Season')
ax.set_ylabel('Points')
ax.set_title('Career Points Comparison: Stephen Curry vs. LeBron James')
plt.show()
